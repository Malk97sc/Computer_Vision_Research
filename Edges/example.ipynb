# %% [markdown]
# # Edge Detection

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

#my functions
from EdgeDetector import EdgeDetector
from Plot import plot_cv, plot_img

# %%
path = "../Data/hummingbird.jpg"
img = cv.imread(path, cv.IMREAD_GRAYSCALE)
img.shape
# Out:
# (667, 1000)

# %%
plot_img(img)

# %% [markdown]
# ## Edges

# %%
detector = EdgeDetector(img)

# %% [markdown]
# ### Sobel

# %%
sobel = detector.sobel()
plot_img(sobel)

# %% [markdown]
# ### Laplacian

# %%
laplace = detector.laplacian()
plot_img(laplace)
