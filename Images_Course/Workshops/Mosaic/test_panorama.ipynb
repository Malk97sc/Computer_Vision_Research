# %% [markdown]
# # Mosaic Creation

# %%
from panoramaSt import Mosaic
from Plot import plot_img

# %%
image_list = []
n = 7

for i in range(n):
    image_list.append(f"data/img{i+1}.png")

for i in range(n):
    print(image_list[i])
# Out:
# data/img1.png
# data/img2.png
# data/img3.png
# data/img4.png
# data/img5.png
# data/img6.png
# data/img7.png

# %% [markdown]
# ## Results

# %%
mosaic = Mosaic(image_list)
panorama = mosaic.create_mosaic()

# %%
plot_img(panorama, size=(26, 12))
