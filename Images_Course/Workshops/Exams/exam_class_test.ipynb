# %%
import pandas as pd
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt

from Plot import plot_img, plot_cv
from Exam import ExamDetection

# %%
path = "../../../Data/exams/AI-HR02.jpg"
img_rgb = cv.imread(path, cv.IMREAD_COLOR_RGB)
img_rgb.shape
# Out:
# (3280, 2552, 3)

# %%
plot_img(img_rgb)

# %%
detector = ExamDetection(img_rgb)

# %%
answers = detector.show_answers()
# Out:
# row: 0, choice: A
# row: 1, choice: B
# row: 2, choice: C
# row: 3, choice: D
# row: 4, choice: B
# row: 5, choice: B
# row: 6, choice: C
# row: 7, choice: A
# row: 8, choice: C
# row: 9, choice: B

# %%
img_result = detector.show_result(answers)
plot_img(img_result)
