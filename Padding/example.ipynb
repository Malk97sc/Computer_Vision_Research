# %% [markdown]
# # Padding Example

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

#my functions
from Padding import padding
from Plot import plot_cv, plot_img

# %%
path = "../Data/hummingbird.jpg"
img = cv.imread(path, cv.IMREAD_COLOR_RGB)
img.shape
# Out:
# (667, 1000, 3)

# %%
plot_img(img)

# %%
kernel = np.ones((5, 5))

padd_img = padding(img, kernel)
plot_img(padd_img)

# %%
plot_cv(padd_img)
